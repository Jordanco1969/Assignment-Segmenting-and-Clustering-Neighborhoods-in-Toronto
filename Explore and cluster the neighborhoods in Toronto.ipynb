# %% [markdown]
# IMPORT MODULES

# %%
import numpy as np

import pandas as pd

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

import folium

from IPython.display import display

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
df=pd.read_csv('postal_code_with_geo.csv')

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.806686 -79.194353
# 1                                     Victoria Village  43.784535 -79.160497
# 2                             Regent Park Harbourfront  43.763573 -79.188711
# 3                      Lawrence Manor Lawrence Heights  43.770992 -79.216917
# 4           Queen's Park Ontario Provincial Government  43.773136 -79.239476
# ..                                                 ...        ...        ...
# ...

# %%
df.drop("Postal Code", axis=1)
# Out:
#               Borough                                      Neighbourhood  \
# 0          North York                                          Parkwoods
# 1          North York                                   Victoria Village
# 2    Downtown Toronto                           Regent Park Harbourfront
# 3          North York                    Lawrence Manor Lawrence Heights
# 4    Downtown Toronto         Queen's Park Ontario Provincial Government
# ..                ...                                                ...
# 98          Etobicoke        The Kingsway Montgomery Road Old Mill North
# 99   Downtown Toronto                               Church and Wellesley
# 100      East Toronto  Business reply mail Processing Centre South Ce...
# 101         Etobicoke  Old Mill South King's Mill Park Sunnylea Humbe...
# 102         Etobicoke  Mimico NW The Queensway West South of Bloor Ki...
#
#       Latitude  Longitude
# 0    43.806686 -79.194353
# 1    43.784535 -79.160497
# ...

# %% [markdown]
# TORONTO LATITUDE AND LONGITUDE

# %%
Latitude, Longitude =43.651070, -79.347015

map_Toronto = folium.Map(location=[Latitude, Longitude], zoom_start=10)

# %% [markdown]
# add markers to map

# %%
for pos_code, borough, neighborhood, lat, lng  in df.values:
    
#    print(pos_code, borough, neighborhood, lat, lng)
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)

# %% [markdown]
# MAP IS SHOW , BUT WITH EDGE BROWSER HAVE BUG ... SEE YOU map_Toronto.html

# %%
map_Toronto.save('map_Toronto.html')
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
